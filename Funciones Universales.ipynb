# %% [markdown]
# # Funciones Universales- Morales Martínez Adriel Josué1951

# %%
import numpy as np

a = np.array([2, 4, 9], float)

# %%
a
# Out:
# array([2., 4., 9.])

# %%
np.sqrt(a)
# Out:
# array([1.41421356, 2.        , 3.        ])

# %%
np.exp(a)
# Out:
# array([7.38905610e+00, 5.45981500e+01, 8.10308393e+03])

# %%
np.log(a)
# Out:
# array([0.69314718, 1.38629436, 2.19722458])

# %% [markdown]
# # Funciones Universales- Morales Martínez Adriel Josué1951

# %%
np.sin(a)
# Out:
# array([ 0.90929743, -0.7568025 ,  0.41211849])

# %%
np.cos(a)
# Out:
# array([-0.41614684, -0.65364362, -0.91113026])

# %%
np.mean(a)
# Out:
# 5.0

# %%
np.std(a)
# Out:
# 2.943920288775949

# %%
np.var(a)
# Out:
# 8.666666666666666
