# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'VarA': ['aa', None, 'cc'],
    'VarB': [20, 30, None],
    'VaraC': [1234, 3456, 6789]
    },
    index = ['Caso1', 'Caso2', 'Caso3']
)
df
# Out:
#        VarA  VarB  VaraC
# Caso1    aa  20.0   1234
# Caso2  None  30.0   3456
# Caso3    cc   NaN   6789

# %%
pd.isnull(df)
# Out:
#         VarA   VarB  VaraC
# Caso1  False  False  False
# Caso2   True  False  False
# Caso3  False   True  False

# %%
df.dropna(subset=["VarA", 'VarB'])
# Out:
#       VarA  VarB  VaraC
# Caso1   aa  20.0   1234

# %%
df.fillna("")
# Out:
#       VarA  VarB  VaraC
# Caso1   aa  20.0   1234
# Caso2       30.0   3456
# Caso3   cc         6789

# %%
df.fillna(df.mean())
# Out:
#        VarA  VarB  VaraC
# Caso1    aa  20.0   1234
# Caso2  None  30.0   3456
# Caso3    cc  25.0   6789
